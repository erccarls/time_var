# %% [markdown]
# ## Tuning DBSCAN for Transient and Time Variabile Sources

# %% [markdown]
# ### The Monte Carlo

# %% [markdown]
# The goal of this notebook is to test DBSCAN's ability to resolve time variable sources in an isotropic and homogenous background, and to determine the algorithms detectability threshold and statistical significance compared to simple binning.  With an eye on time variability at the galactic center, this will also serve as a case study to detect low significance, time variable point sources that are otherwise lost in the full time-integrated signal.  This may offer a method to expand, for example, 2FGL into the time domain.
#
# To demonstrate viability we will write a Monte-Carlo which produces a single isolated source in the center of the simulation volume.  The signal template will simply be cylindrically symmetric, with the axis pointing temporally, and the radial (spatial) events distributed according to a Gaussian with 68% containment radius matching the average of the FERMI-LAT performance specifications for a given energy range.  (Found at:http://www.slac.stanford.edu/exp/glast/groups/canda/lat_Performance.htm)  For the test case we will assume this is 1 degree.
#
# As input parameters we will have the number of signal photons when the burst is on/off, \\( N_{on}^{sig}, N_{off}^{sig} \\), the sources burst-time \\(t_{burst}\\), the scale-factor for the time component of DBSCAN's metric \\(a\\).
#
# Let us first generate the simulation data.  Later we will discuss the DBSCAN aspects.  In this code block we generate a 10x10 (deg) x48 (month) box.  We then have a background count specified by \\(N_{bg}=1000\\).  For now, we also assume \\( N_{off}^{sig}=0 \\) so that the source is isolated in time.  The source is then placed at the center of the box, with \\( N_{on}^{sig}\\) photons distributed isotropically over a time \\(t_{burst}\\).

# %%
import cPickle as pickle, numpy as np, matplotlib.pyplot as plt
import psf# Module for gaussian PSF convolution

# Universal Simulation Parameters
sizeX,sizeY,sizeT = 10.,10.,1. # Define box size
N_bg = 1000 # Number of background events to be distributed randomly
r_68 = 1.0 # Spatial PSF size in degrees 

# Define a function to run the simulation given a set of input parameters
# Optimized via numpy's vector routines
def RunSim(N_sig_on, N_sig_off, t_burst):
    # Generate the signal
    X,Y,T = np.zeros(N_sig_on), np.zeros(N_sig_on), (np.random.ranf(N_sig_on)-.5)*t_burst
    X,Y,T = np.append(np.zeros(N_sig_off),X), np.append(np.zeros(N_sig_off),Y), np.append((np.random.ranf(N_sig_off)-.5)*sizeT,T)
    # Shift the signal photons using the PSF
    X,Y = psf.ApplyGaussianPSF(XMASTER=X,YMASTER=Y,r_68=r_68 )
    # Generate the background photons-Don't shift these by the PSF
    X = np.append(X,(np.random.ranf(N_bg)-.5)*sizeX)
    Y = np.append(Y,(np.random.ranf(N_bg)-.5)*sizeY)
    T = np.append(T,(np.random.ranf(N_bg)-.5)*sizeT)
    return X,Y,T
# Run a simulation with 500 photons distributed 
X,Y,T = RunSim(N_sig_on=500,N_sig_off=500, t_burst=1/48.)

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(0,figsize=(10,4))
ax = fig.add_subplot(121, projection='3d')
ax.scatter(X,Y,T, s=2)
plt.xlabel('x')
plt.ylabel('y')
ax.set_zlabel('t')


# Run a simulation with 5000 photons distributed 
X,Y,T = RunSim(N_sig_on=5000,N_sig_off=0,t_burst=100)

ax = fig.add_subplot(122, projection='3d')
ax.scatter(X,Y,T, s=2)
plt.xlabel('x')
plt.ylabel('y')
ax.set_zlabel('t')

plt.show()

# %% [markdown]
# As a reality check to ensure our MC is correctly simulating, we plot a few example cases above to ensure we have a centered, cylindrically symmetric source with an axis in the time direction.  These look correct so we will now attempt to profile DBSCAN in 3-dimensions.

# %% [markdown]
# ### Tuning DBSCAN for 3-Dimensions

# %% [markdown]
# We wish to determine three things:
#
# 1. What scale factor for the time coordinate is relevant for a cluster with a known length? In other words, once we know the time variability of our source, we need to choose the appropriate metric for DBSCAN which maximizes the statistical significance of the cluster.  In a general search algorithm, we will likely need to scan over a range of scale factors and a transient source would then show up as a resonance in a plot of scale factor \\(a\\) vs cluster significance \\(\sigma\\).
#
# 2. How stable is the algorithm under changes in DBSCAN parameters for a real source? We would like to understand whether or not our algorithm is sensitive to small changes in \\(N_{min}\\) or \\(a\\).  The less sensitivity exhibited, the more robust the results will be.  In addition, it will allow for less granularity when scanning over the scale factor, resulting in a much more (computationally) efficient search algorithm.
#
# 3. What is the detection threshold in terms of overdensity compared to the backgrounds and how do the significances change when we lower \\(N_{min}\\) or change \\(a\\)?  From previous 2-dimensional studies of these properties, it is generally better to begin with \\(N_{min}=N_{bg}^{exp.}+3 \sqrt{N_{bg}^{exp.}}\\) as the threshold, where \\(N_{bg}^{exp.}\\) is the expected mean background count for a given epsilon, but this decreases the number of detectable real clusters.  We will characterize this again for the 3-d case.
#
# Let us begin to answer these quesetions by simulating a source with \\(t_{burst}=1\\) month over the 4-year Fermi-LAT mission lifetime.

# %%
import DBSCAN,MCSTATS,dbscan_indexed
numSims = 4# number of simulations for each MC
aList = np.logspace(0,2,30) # scale factors to scan over
N_sigList = range(0,101,20)

MS,MC = [],[]

for N_sig in N_sigList:
    mcSims=[RunSim(N_sig_on=N_sig,N_sig_off=0,t_burst=1/48.) for i in range(numSims)]
    dbscanResults,sigs = [],[]
    
    for a in aList:
        bgDensity = N_bg/(sizeX*sizeY) # 2d mean background density
        #expBG     = bgDensity *4/3.* np.pi*r_68**3 * (1./a) # expected number of events in a cylinder that circumscribes 
        expBG     = bgDensity / a # expected number of events in a cylinder that circumscribes 
        nMin = expBG + 3. * np.sqrt(expBG)
        print nMin
        if nMin<3.: nMin=3
        scan = MCSTATS.DBSCAN_Compute_Clusters(mcSims, eps=r_68,min_samples=nMin, timeScale=a,numProcs=4,plot=False)
        dbscanResults.append(scan)
        sigs.append(MCSTATS.Cluster_Sigs_BG_3d(scan,BGDensity=N_bg/float(sizeX*sizeY), totalTime = sizeT))
    # Compute averages 
    counts,sigmas = [],[]
    for b in sigs:
        count,avgSig = 0., 0.
        for s in b:
            count+=len(s)
            if len(s)>0:
                avgSig += np.max(s)
        counts.append(count/float(len(b)))
        sigmas.append(avgSig/float(len(b)))
        
    MS.append(sigmas)
    MC.append(counts)
# Out:
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805
# 19.4868329805

# %%
plt.figure(0,figsize=(10,4))
maxSig = []

for i in range(len(N_sigList)):
    N_sig,sigmas,counts = N_sigList[i],MS[i],MC[i] 
    plt.subplot(121)
    plt.plot(aList,sigmas)
    plt.vlines(bgDensity * 4./3.* np.pi*r_68**3 , .1,100,label='Expected BG Count=1',linestyle='-.') # expected number of events in a cylinder that circumscribes  )
    plt.xlabel(r'Scale factor $a$ [deg/mo]')
    plt.ylabel(r'Mean Significance $\sigma$')
    plt.yscale('log')
    plt.xscale('log')
    
    plt.subplot(122)
    if N_sig==0: plt.plot(aList,counts,label=r'BG Only',ls='--')
    else:plt.plot(aList,counts,label=r'$N_{sig}^{on}=$' + str(N_sig) + r"$\gamma$")
        
    plt.ylabel(r'Detected Clusters $N_{clusters}$')
    plt.xlabel(r'Scale factor $a$ [deg/mo]')
    #plt.yscale('log')
    #plt.xscale('log')
    
    if aList[np.argmax(sigmas)]>1: maxSig.append(aList[np.argmax(sigmas)])

plt.vlines(bgDensity * 4./3.* np.pi*r_68**3 , .1,10**2,label='Expected BG Count=1',linestyle='-.') # expected number of events in a cylinder that circumscribes  )
plt.legend(ncol=2,bbox_to_anchor=(2.3, 1.00))
        
print 'Average scale factor for max significance: ', np.mean(maxSig)
plt.show()
# Out:
# Average scale factor for max significance:  21.1527862832

# %% [markdown]
# Above, we plot the average cluster significance (left) and number of clusters (right) as a function of the DBSCAN scale factor \\(a\\) for several different values of \\(N_{sig}^{on}\\).  We see that the region that maximizes significance is coincident with the region that detect only one cluster (no false clusters detected).  The region also appears to be stable over a reasonably large range of scale factors.
#
# Furthermore, the maximum significance occurrs at the theoretical maximum (within the granularity of the simulations).  This maximium is independent of the number of signal photons and is found by choosing the scale factor which forms the most spherical cluster (may want to correct metric to be cylindrical rather than ellipsoidal).  For a PSF of 1 deg. radius, this gives
#
# $$a = \frac{1}{t_{burst}} \frac{\Delta T}{\Delta X}=1~month \times \frac{48}{10}=4.8~month/deg.$$

# %%
import DBSCAN,MCSTATS,dbscan_indexed
numSims = 16 # number of simulations for each MC
N_sig = 200
aList = np.logspace(-1,2,30) # scale factors to scan over
t_burstList=np.linspace(1,6,6)


MS,MC = [],[]


for t_burst in t_burstList:
    mcSims=[RunSim(N_sig_on=N_sig,t_burst=t_burst) for i in range(numSims)]
    dbscanResults,sigs = [],[]
    
    for a in aList:
        bgDensity = N_bg/(sizeX*sizeY*sizeT)*4./3.*pi*r_68*r_68 # mean background density
        nMin = bgDensity + 3. * np.sqrt(bgDensity)
        scan = MCSTATS.DBSCAN_Compute_Clusters(mcSims, eps=r_68,min_samples=nMin, timeScale=a,numProcs=4,plot=False)
        dbscanResults.append(scan)
        sigs.append(MCSTATS.Cluster_Sigs_BG_3d(scan,BGDensity=N_bg/float(sizeX*sizeY), totalTime = sizeT))
    # Compute averages 
    counts,sigmas = [],[]
    for a in sigs:
        count,avgSig = 0., 0.
        for s in a:
            count+=len(s)
            if len(s)>0:
                avgSig += np.max(s)
        counts.append(count/float(len(a)))
        sigmas.append(avgSig/float(len(a)))
        
    MS.append(sigmas)
    MC.append(counts)

# %%
plt.figure(0,figsize=(6,10))
maxSig = []

for i in range(len(t_burstList)):
    N_sig,sigmas,counts = t_burstList[i],MS[i],MC[i] 
    plt.subplot(211)
    plt.plot(aList,sigmas)
    plt.xlabel(r'Scale factor $a$ [deg/month]')
    plt.ylabel(r'Mean Significance $\sigma$')
    plt.yscale('log')
    plt.xscale('log')
    plt.ylim((1,30))
    
    plt.subplot(212)
    plt.plot(aList,counts,label=r'$t_{burst}=$' + str(t_burstList[i]) + r" months")
    plt.yscale('log')
    plt.xscale('log')
    plt.ylabel(r'Detected Clusters $N_{clusters}$')
    plt.xlabel(r'Scale factor $a$ [deg/month]')
    
    plt.legend(ncol=1,bbox_to_anchor=(1.6, 1.00))
    
    print 't_burst, a_max ', t_burstList[i], aList[np.argmax(sigmas)]

plt.show()
# Out:
# t_burst, a_max  1.0 3.56224789026
# t_burst, a_max  2.0 2.21221629107
# t_burst, a_max  3.0 2.21221629107
# t_burst, a_max  4.0 2.21221629107
# t_burst, a_max  5.0 1.7433288222
# t_burst, a_max  6.0 1.37382379588

# %% [markdown]
# \\(N_{min}\\) and \\(a\\) Cross-Checks

# %%
numSims = 16 # number of simulations for each MC
aList = np.linspace(1,20,21) # scale factors to scan over
nMinSigmas = np.linspace(0,5,20)

mcSims=[RunSim(N_sig_on=100,t_burst=1) for i in range(numSims)]
MS,MC = np.zeros(shape=(len(aList), len(nMinSigmas))) ,np.zeros(shape=(len(aList), len(nMinSigmas)) )


for i in range(len(aList)):
    for j in range(len(nMinSigmas)):
        dbscanResults,sigs = [],[]
        
        bgDensity = N_bg/(sizeX*sizeY*sizeT)*4./3.*pi*r_68*r_68 # mean background density
        nMin = bgDensity + nMinSigmas[j] * np.sqrt(bgDensity)
        scan = MCSTATS.DBSCAN_Compute_Clusters(mcSims, eps=r_68,min_samples=nMin, timeScale=aList[i],numProcs=4,plot=False)
        dbscanResults.append(scan)
        sigs.append(MCSTATS.Cluster_Sigs_BG_3d(scan,BGDensity=N_bg/float(sizeX*sizeY), totalTime = sizeT))
        # Compute averages 
        counts,sigmas = [],[]
        for a in sigs:
            count,avgSig = 0., 0.
            for s in a:
                count+=len(s)
                if len(s)>0:
                    avgSig += np.max(s)
        MC[i][j] = count/float(len(a))
        MS[i][j] = avgSig/float(len(a))

# %%
plt.figure(0,figsize=(12,4))
plt.subplot(121)
cs = plt.contourf(nMinSigmas,aList,MS,levels=np.linspace(0,15,61))
plt.xlabel(r'$N_{min,\sigma}$')
plt.ylabel(r'Scale Factor $a$')
cbar = plt.colorbar(cs)
plt.title('Average Significance $\sigma$')

plt.subplot(122)
cs = plt.contourf(nMinSigmas,aList,MC,levels=np.linspace(0,15,61))
cbar = plt.colorbar(cs)
cs = plt.contour(nMinSigmas,aList,MC,levels=[0,.75,1,2],colors='k')
plt.clabel(cs)
plt.xlabel(r'$N_{min,\sigma}$')
plt.title('Average Number of Clusters $N_{clusters}$')

plt.show()
